# %%
# !pip install pandas numpy matplotlib
# Out:
# Requirement already satisfied: pandas in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (3.0.5)
# Requirement already satisfied: numpy in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (2.5.2)
# Requirement already satisfied: matplotlib in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (3.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /Users/jakemasaschi/Documents/GitHub/cosc470_2026/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Step 1: Generate data using numpy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Set seed so all students get the exact same random numbers
np.random.seed(42)

# 1. Create an array of 100 days (Day 1 to 100)
days = np.arange(1, 101)
print(f"First 5 days: {days[:5]}")

# 2. Simulate 100 days of Temperatures (Average 75 degrees, standard deviation of 10)
temperatures = np.random.normal(loc=75, scale=10, size=100)
temperatures = np.round(temperatures, 1) # Round to 1 decimal place

# 3. Simulate Sales (Ice cream goes up when it's hot, coffee goes down)
# Add a little random noise so the data doesn't look completely artificial
ice_cream_sales = (temperatures * 4) + np.random.normal(0, 20, 100)
coffee_sales = (400 - (temperatures * 3)) + np.random.normal(0, 15, 100)

# Clean up negative sales (can't sell less than 0 items)
ice_cream_sales = np.maximum(ice_cream_sales, 0)
ice_cream_sales = np.round(ice_cream_sales, 1) # Round to 1 decimal place
coffee_sales = np.maximum(coffee_sales, 0)
coffee_sales = np.round(coffee_sales, 1) # Round to 1 decimal place

print(f"First 5 temperatures: {temperatures[:5]}")
print(f"First 5 ice cream sales: {ice_cream_sales[:5]}")
print(f"First 5 coffee sales: {coffee_sales[:5]}")
# Out:
# First 5 days: [1 2 3 4 5]
# First 5 temperatures: [80.  73.6 81.5 90.2 72.7]
# First 5 ice cream sales: [291.7 286.  319.1 344.8 287.6]
# First 5 coffee sales: [165.4 187.6 171.7 145.2 161.2]

# %% [markdown]
# # Step 2: Organize the data

# %%
# 1. Create the DataFrame to organize our arrays into columns
df = pd.DataFrame({
    'Day': days,
    'Temperature': temperatures,
    'Ice_Cream': np.round(ice_cream_sales),
    'Coffee': np.round(coffee_sales)
})

# 2. Basic Exploration 
# print(df.head())
# print(df.describe())
newdf = df.describe()
print(newdf)
print(newdf["Day"]["mean"])

# 3. Feature Engineering: Create a new column for Total Items Sold
df['Total_Sales'] = df['Ice_Cream'] + df['Coffee']

# 4. Data Filtering: Let's analyze "Heatwave" days (over 85 degrees)
heatwave_df = df[df['Temperature'] > 85]
# print("Heatwave Days:")
# print(heatwave_df)

# Find the single day with the highest total sales
best_day = df[df['Total_Sales'] == df['Total_Sales'].max()]

# print("Our Best Sales Day:")
# print(best_day)
# Out:
#               Day  Temperature   Ice_Cream      Coffee
# count  100.000000   100.000000  100.000000  100.000000
# mean    50.500000    73.963000  296.310000  179.060000
# std     29.011492     9.080934   38.651694   28.956889
# min      1.000000    48.800000  201.000000  107.000000
# 25%     25.750000    69.000000  273.000000  160.750000
# 50%     50.500000    73.700000  292.500000  182.000000
# 75%     75.250000    79.100000  318.250000  196.250000
# max    100.000000    93.500000  401.000000  242.000000
# 50.5

# %% [markdown]
# # Step 3: Visualizing the business

# %%
# Create a figure with two side-by-side plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# --- Plot 1: Scatter Plot (Correlation) ---
# Does temperature really affect sales? Let's prove it visually.
ax1.scatter(df['Temperature'], df['Ice_Cream'], color='blue', alpha=0.6, label='Ice Cream')
ax1.scatter(df['Temperature'], df['Coffee'], color='red', alpha=0.6, label='Coffee')
ax1.set_title('Sales Volume vs. Temperature')
ax1.set_xlabel('Temperature (°F)')
ax1.set_ylabel('Items Sold')
ax1.legend()
ax1.grid(True, alpha=0.3)

# --- Plot 2: Line Graph (Trends over Time) ---
# How did our total sales look over the 100 days?
ax2.plot(df['Day'], df['Total_Sales'], color='green', linewidth=2)
ax2.set_title('Total Daily Sales Over 100 Days')
ax2.set_xlabel('Day')
ax2.set_ylabel('Total Items Sold')
ax2.grid(True, alpha=0.3)


# Display the graphs cleanly
plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 4: Challenge

# %%
lemonade_sales = (temperatures * 5) + np.random.normal(0, 25, 100)
lemonade_sales = np.maximum(lemonade_sales, 0)
lemonade_sales = np.round(lemonade_sales, 1)

df['Lemonade'] = lemonade_sales

print(f"First 5 lemonade sales: {lemonade_sales[:5]}")
print(df.describe())
# Out:
# First 5 lemonade sales: [423.2 415.7 372.5 465.1 347.2]
#               Day  Temperature   Ice_Cream      Coffee    Lemonade
# count  100.000000   100.000000  100.000000  100.000000  100.000000
# mean    50.500000    73.963000  296.310000  179.060000  366.932000
# std     29.011492     9.080934   38.651694   28.956889   47.693705
# min      1.000000    48.800000  201.000000  107.000000  239.200000
# 25%     25.750000    69.000000  273.000000  160.750000  340.725000
# 50%     50.500000    73.700000  292.500000  182.000000  368.050000
# 75%     75.250000    79.100000  318.250000  196.250000  396.925000
# max    100.000000    93.500000  401.000000  242.000000  493.900000
